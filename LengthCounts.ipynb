# %%
# %%writefile length_counts.py

from mrjob.job import MRJob
import re


class LengthCounts(MRJob):

    def mapper(self, _, line):
        import os
        for word in re.sub("[^a-zA-Z]+"," ",line).lower().split():
            file_name = os.getenv('mapreduce_map_input_file')
            yield (file_name, len(word))

    def reducer(self, key, values)
        yield (key, len(set(values)))


if __name__ == '__main__':
    LengthCounts.run()
# Out:
# Overwriting length_counts.py

# %%
# %run length_counts.py americana.txt*
# Out:
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# No configs found; falling back on auto-configuration
# ...
